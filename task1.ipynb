# %%
import numpy as np

scale = 1.0
array = np.random.exponential(scale, (4, 4))

print(array)
# Out:
# [[0.29528124 3.24753539 0.01239986 0.98177996]
#  [2.40164785 0.3565195  0.38499993 0.80038097]
#  [0.36859451 0.98934785 0.06199703 1.42210814]
#  [2.91661584 0.4432583  0.1471988  2.43964448]]

# %%
import numpy as np
import matplotlib.pyplot as plt


scale = 1.0
n_samples = 100000


exponential_data = np.random.exponential(scale, n_samples)
uniform_data = np.random.rand(n_samples)
normal_data = np.random.randn(n_samples)

plt.hist(uniform_data, density=True, bins=bins, histtype="step", color="blue", label="Uniform")
plt.hist(normal_data, density=True, bins=bins, histtype="step", color="green", label="Normal")
plt.hist(exponential_data, density=True, bins=bins, histtype="step", color="red", label="Exponential")

plt.legend(loc="upper right")
plt.title("Random Distributions")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)

z = x**2 + y**2

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot_surface(x, y, z, cmap='viridis')

ax.set_title('3D plot of Z = X^2 + Y^2')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# !wget -q https://elitedatascience.com/wp-content/uploads/2022/07/Pokemon.csv

df = pd.read_csv('Pokemon.csv', index_col=0, encoding='latin')

features = ['HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed']
data = df[features]

pearson_corr = data.corr(method='pearson')

spearman_corr = data.corr(method='spearman')

plt.figure(figsize=(10, 8))
sns.heatmap(pearson_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1, linewidths=.5)
plt.title('Pearson Correlation Heatmap')
plt.show()

plt.figure(figsize=(10, 8))
sns.heatmap(spearman_corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1, linewidths=.5)
plt.title('Spearman Rank Correlation Heatmap')
plt.show()
